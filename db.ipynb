# %%
# Load the SQL magic extension
# https://github.com/ploomber/jupysql
# this extension allows us to connect to DBs and issue SQL commands
# %load_ext sql

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy import text, inspect

# %%
engine = create_engine('sqlite:///kbo_database.db')
print(type(engine))
# Out:
# <class 'sqlalchemy.engine.base.Engine'>

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
# Code to drop belgium_regions table if it exists

# with engine.connect() as conn:
#     conn.execute(text("DROP TABLE IF EXISTS belgium_regions"))
#     conn.commit()

# inspector = inspect(engine)
# print(inspector.get_table_names())

# %%
from sqlalchemy import Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

class BelgiumRegion(Base):
    __tablename__ = "belgium_regions"

    id = Column(Integer, primary_key=True)
    region_code = Column(String, nullable=False)
    post_code = Column(String, nullable=False)
    region_name_fr = Column(String, nullable=False)


Base.metadata.create_all(engine)
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['activity', 'address', 'belgium_regions', 'branch', 'code', 'contact', 'denomination', 'enterprise', 'establishment', 'meta']
# /var/folders/n4/xhm5c1x102q3rdg91bgwysbw0000gn/T/ipykernel_90583/40714184.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
# Create new table for Belgium regions. Only run once
import csv

with open("georef-belgium-postal-codes.csv", newline="", encoding="utf-8") as csvfile:
    reader = csv.DictReader(csvfile, delimiter=";")
    for row in reader:
        entry = BelgiumRegion(
            region_code=row["Région code"],
            post_code=row["Post code"],
            region_name_fr=row["Région name (French)"]
        )
        session.add(entry)

session.commit()
session.close()

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['activity', 'address', 'belgium_regions', 'branch', 'code', 'contact', 'denomination', 'enterprise', 'establishment', 'meta']

# %%
def execute_query(query):
    with Session() as session:
        result = session.execute(text(query))
        for row in result:
            print(row)

# %%
inspector = inspect(engine)
print(inspector.get_columns("enterprise"))
# Add a new column to the enterprise table (RUN ONCE)
with Session() as session:
    session.execute(text("""
    ALTER TABLE enterprise
    ADD COLUMN StartDate_ISO TEXT;
    """))
    session.commit()
# Out:
# [{'name': 'EnterpriseNumber', 'type': TEXT(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'Status', 'type': TEXT(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'JuridicalSituation', 'type': INTEGER(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'TypeOfEnterprise', 'type': INTEGER(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'JuridicalForm', 'type': REAL(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'JuridicalFormCAC', 'type': REAL(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'StartDate', 'type': TEXT(), 'nullable': True, 'default': None, 'primary_key': 0}, {'name': 'StartDate_ISO', 'type': TEXT(), 'nullable': True, 'default': None, 'primary_key': 0}]
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# OperationalError: duplicate column name: StartDate_ISO
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[47], line 5
#       3 # Add a new column to the enterprise table (RUN ONCE)
#       4 with Session() as session:
# ----> 5     session.execute(text("""
#       6     ALTER TABLE enterprise
#       7     ADD COLUMN StartDate_ISO TEXT;
#       8     """))
#       9     session.commit()
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2365, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2305 def execute(
#    2306     self,
#    2307     statement: Executable,
#    (...)   2313     _add_event: Optional[Any] = None,
#    2314 ) -> Result[Any]:
#    2315     r"""Execute a SQL expression construct.
#    2316
#    2317     Returns a :class:`_engine.Result` object representing
#    (...)   2363
#    2364     """
# -> 2365     return self._execute_internal(
#    2366         statement,
#    2367         params,
#    2368         execution_options=execution_options,
#    2369         bind_arguments=bind_arguments,
#    2370         _parent_execute_state=_parent_execute_state,
#    2371         _add_event=_add_event,
#    2372     )
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/orm/session.py:2260, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2251     result: Result[Any] = compile_state_cls.orm_execute_statement(
#    2252         self,
#    2253         statement,
#    (...)   2257         conn,
#    2258     )
#    2259 else:
# -> 2260     result = conn.execute(
#    2261         statement, params or {}, execution_options=execution_options
#    2262     )
#    2264 if _scalar_result:
#    2265     return result.scalar()
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
# -> 1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/sql/elements.py:523, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     521     if TYPE_CHECKING:
#     522         assert isinstance(self, Executable)
# --> 523     return connection._execute_clauseelement(
#     524         self, distilled_params, execution_options
#     525     )
#     526 else:
#     527     raise exc.ObjectNotExecutableError(self)
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1637, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1625 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1626     "compiled_cache", self.engine._compiled_cache
#    1627 )
#    1629 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1630     dialect=dialect,
#    1631     compiled_cache=compiled_cache,
#    (...)   1635     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1636 )
# -> 1637 ret = self._execute_context(
#    1638     dialect,
#    1639     dialect.execution_ctx_cls._init_compiled,
#    1640     compiled_sql,
#    1641     distilled_parameters,
#    1642     execution_options,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     elem,
#    1646     extracted_params,
#    1647     cache_hit=cache_hit,
#    1648 )
#    1649 if has_events:
#    1650     self.dispatch.after_execute(
#    1651         self,
#    1652         elem,
#    (...)   1656         ret,
#    1657     )
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840     return self._exec_insertmany_context(dialect, context)
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1982, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1979     result = context._setup_result_proxy()
#    1981 except BaseException as e:
# -> 1982     self._handle_dbapi_exception(
#    1983         e, str_statement, effective_parameters, cursor, context
#    1984     )
#    1986 return result
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2351, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2349 elif should_wrap:
#    2350     assert sqlalchemy_exception is not None
# -> 2351     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2352 else:
#    2353     assert exc_info[1] is not None
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1963, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1961                 break
#    1962     if not evt_handled:
# -> 1963         self.dialect.do_execute(
#    1964             cursor, str_statement, effective_parameters, context
#    1965         )
#    1967 if self._has_events or self.engine._has_events:
#    1968     self.dispatch.after_cursor_execute(
#    1969         self,
#    1970         cursor,
#    (...)   1974         context.executemany,
#    1975     )
#
# File ~/kbo-project/venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:943, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     942 def do_execute(self, cursor, statement, parameters, context=None):
# --> 943     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) duplicate column name: StartDate_ISO
# [SQL:
#     ALTER TABLE enterprise
#     ADD COLUMN StartDate_ISO TEXT;
#     ]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
with Session() as session:
    # Update the StartDate_ISO column with the formatted date
    session.execute(text("""
    UPDATE enterprise
    SET StartDate_ISO = substr(StartDate, 7, 4) || '-' || substr(StartDate, 4, 2) || '-' || substr(StartDate, 1, 2);
    """))
    session.commit()

# %%
# Regional distribution of BELGIAN enterprises
query1= """
SELECT
	COUNT(DISTINCT EnterpriseNumber) AS enterprise_count,
	region_code,
	region_name_fr
FROM
	enterprise
	INNER JOIN address ON address.EntityNumber = enterprise.EnterpriseNumber
	INNER JOIN belgium_regions ON address.Zipcode = belgium_regions.post_code
WHERE region_code IS NOT NULL
    AND region_code != ''
GROUP BY
	region_code
ORDER BY enterprise_count DESC
"""
execute_query(query1)
# Out:
# (647538, '02000', 'Région flamande')
# (247945, '03000', 'Région wallonne')
# (175914, '01000', 'Région de Bruxelles-Capitale')

# %%
# distribution of activity groups
query2 = """
SELECT
    COUNT(activity.EntityNumber) AS count,
    activity.ActivityGroup as "Activity Group",
    code.Description as "Description"
FROM
    activity
    LEFT JOIN code ON code.Code = activity.ActivityGroup 
        AND code.Category = 'ActivityGroup'
        AND code.Language = 'NL'
GROUP BY
    activity.ActivityGroup, code.Description
ORDER BY count DESC
"""

execute_query(query2)
# Out:
# (28855664, 3, 'Activiteiten')
# (6487053, 1, 'BTW-activiteiten')
# (1219587, 6, 'RSZ-activiteiten')
# (25800, 7, 'Activiteiten gesubsideerd onderwijs')
# (6964, 5, 'RSZPPO-activiteiten')
# (2423, 4, 'Activiteiten federaal openbaar ambt')

# %%
# distribution of juridical form
query3 = """
SELECT
    COUNT(enterprise.JuridicalForm) AS entity_count,
    Description,
    enterprise.JuridicalForm
FROM
    enterprise
    LEFT JOIN code ON code.Code = enterprise.JuridicalForm 
        AND code.Category = 'JuridicalForm'
GROUP BY
    enterprise.JuridicalForm
HAVING entity_count > 0
ORDER BY entity_count DESC
"""

execute_query(query3)
# Out:
# (1480152, 'Besloten Vennootschap', 610.0)
# (417639, 'Association sans but lucratif', 17.0)
# (325335, 'Association des copropriétaires', 70.0)
# (259623, 'Besloten vennootschap met beperkte aansprakelijkheid', 15.0)
# (242025, 'Aktiengesellschaft', 14.0)
# (202728, 'Ausländische Einheit', 30.0)
# (142056, 'Commanditaire vennootschap', 612.0)
# (83211, 'Gesellschaften oder Vereinigungen ohne Rechtspersönlichkeit', 721.0)
# (74664, 'Offene Handelsgesellschaft', 11.0)
# (48546, 'Einfache Kommanditgesellschaft', 12.0)
# (36447, 'Ausländische Einheit ohne Niederlassung in Belgien mit einem Fiskalvertreter für die MwSt.', 235.0)
# (24960, 'BTW-eenheid', 3.0)
# (21567, 'Coöperatieve vennootschap (oud statuut)', 16.0)
# (14610, 'Etablissement public', 124.0)
# (12333, 'Coöperatieve vennootschap met beperkte aansprakelijkheid', 8.0)
# (11694, 'Ausländische Einheit mit einer Immobilie in Belgien (mit Rechtspersönlichkeit)', 230.0)
# (8586, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid', 6.0)
# (7506, 'Association internationale sans but lucratif', 125.0)
# (6735, 'Fondation privée', 26.0)
# (5259, 'Coöperatieve vennootschap', 706.0)
# (5034, 'Krankenkasse / Gesellschaft auf Gegenseitigkeit / Krankenkassenlandesverband', 19.0)
# (3849, 'Beroepsvereniging', 20.0)
# (2793, 'Forme légale inconnue (ONSS)', 999.0)
# (2370, 'Internationale wetenschappelijke organisatie van Belgisch recht', 22.0)
# (2196, "Fondation d'utilité publique", 29.0)
# (1701, "Centre public d'action sociale", 412.0)
# (1695, 'Stad / gemeente', 411.0)
# (1128, 'Landbouwvennootschap', 25.0)
# (1083, 'Ausländische oder internationale öffentliche Einrichtungen', 160.0)
# (1026, 'Commanditaire vennootschap op aandelen', 13.0)
# (996, 'Entwässerungsgenossenschaft / Bewässerungsgenossenschaft', 129.0)
# (897, 'Autonome Gemeinderegie', 418.0)
# (837, 'Andere Rechtsform', 151.0)
# (804, 'Europees economisch samenwerkingsverband', 65.0)
# (732, 'Andere privaatrechtelijke vorm met rechtspersoonlijkheid', 51.0)
# (600, 'Buitenlandse onderneming zonder Belgische vestiging genoteerd op de beurs', 453.0)
# (558, 'Lokale Polizeizone', 413.0)
# (519, "Etablissement d'utilité publique", 18.0)
# (417, 'Organisme de financement de pensions', 2.0)
# (402, 'Economisch samenwerkingsverband', 60.0)
# (372, 'Association de CPAS', 420.0)
# (366, 'Beim LPA eingetragene Stellen', 451.0)
# (330, 'Coöperatieve vennootschap met beperkte aansprakelijkheid met een sociaal oogmerk', 508.0)
# (246, 'Besloten Vennootschap van publiek recht', 616.0)
# (228, 'Naamloze vennootschap van publiek recht', 114.0)
# (219, 'Association de projet', 415.0)
# (180, 'Ministerie van Binnenlandse Zaken', 379.0)
# (180, "Association d'assurances mutuelles / Caisse commune d'assurances de droit privé", 21.0)
# (162, 'Association chargée de mission (Région flamande)', 417.0)
# (141, 'Andere federale dienst', 303.0)
# (129, 'Autorité de la Région flamande et de la Communauté flamande', 310.0)
# (114, 'Ausländische Einheit mit einer Immobilie in Belgien (ohne Rechtspersönlichkeit)', 454.0)
# (114, 'Coöperatieve vennootschap van publiek recht (oud statuut)', 116.0)
# (105, 'Arbeitsgemeinschaft', 722.0)
# (102, 'Besloten vennootschap met beperkte aansprakelijkheid met een sociaal oogmerk', 515.0)
# (99, 'Hilfeleistungszone', 422.0)
# (96, 'Association étrangère privée avec établissement en Belgique', 23.0)
# (81, 'Association sans but lucratif de droit public', 117.0)
# (78, 'Autonome Provinzialregie', 419.0)
# (78, 'Association prestataire de services (Région flamande)', 416.0)
# (72, 'Beroepsvereniging / Orde', 123.0)
# (60, 'Intercommunale', 414.0)
# (57, 'Bei der Verwaltung der Pensionen eingetragene Stelle', 452.0)
# (54, 'Gesellschaft des allgemeinen Rechts', 702.0)
# (48, 'Autorité provinciale', 400.0)
# (42, 'Autorité de la Communauté française', 340.0)
# (39, 'Europese vennootschap (Societas Europaea)', 27.0)
# (36, 'Federale overheidsdienst', 301.0)
# (30, 'Aktiengesellschaft mit sozialer Zielsetzung', 514.0)
# (30, 'Autorité de la Région de Bruxelles-Capitale', 330.0)
# (30, 'Coöperatieve vennootschap met beperkte aansprakelijkheid, bij wijze van deelneming', 9.0)
# (27, 'Einfache Kommanditgesellschaft mit sozialer Zielsetzung', 512.0)
# (27, 'Coöperatieve vennootschap met beperkte aansprakelijkheid van publiek recht', 108.0)
# (24, 'Autorité de la Région wallonne', 320.0)
# (21, 'Autorité de la Communauté germanophone', 350.0)
# (21, 'Europese politieke partij', 217.0)
# (21, 'Europese Coöperatieve Vennootschap', 1.0)
# (18, 'Coöperatieve vennootschap van publiek recht', 716.0)
# (18, 'Ministerie van het Waalse Gewest', 388.0)
# (18, 'Europees economisch samenwerkingsverband zonder zetel met vestiging in België (EESV)', 265.0)
# (15, 'Divers sans personnalité juridique', 790.0)
# (15, 'Ministerie van de Franse Gemeenschap', 386.0)
# (15, 'Europese politieke stichting', 218.0)
# (15, 'Kongolese vennootschap', 40.0)
# (12, 'Economisch samenwerkingsverband met een sociaal oogmerk', 560.0)
# (12, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid met een sociaal oogmerk', 506.0)
# (12, 'Ministerie van de Vlaamse Gemeenschap', 385.0)
# (12, 'Rijk, Provincie, Gewest, Gemeenschap', 110.0)
# (9, 'Andere', 393.0)
# (6, 'Ministerie van Economische Zaken', 370.0)
# (6, 'Association internationale sans but lucratif de droit public', 325.0)
# (6, 'Föderaler öffentlicher Programmierungsdienst', 302.0)
# (6, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid, bij wijze van deelneming', 7.0)
# (3, 'Gewerkschaft', 724.0)
# (3, 'Andere vorm met een sociaal oogmerk van publiek recht', 651.0)
# (3, 'Commanditaire vennootschap van publiek recht', 617.0)
# (3, 'Commanditaire vennootschap op aandelen met een sociaal oogmerk', 513.0)
# (3, 'Offene Handelsgesellschaft mit sozialer Zielsetzung', 511.0)
# (3, 'Ministerie van het Brusselse Hoofdstedelijk Gewest', 387.0)
# (3, 'Diensten van de Eerste Minister', 383.0)
# (3, 'Ministerie van Justitie', 380.0)
# (3, 'Ministerie van Middenstand', 373.0)
# (3, 'Ministerie van Buitenlandse Zaken, Buitenlandse handel en Ontwikkelingssamenwerking', 371.0)
# (3, 'Berg van Barmhartigheid', 127.0)
# (3, 'Einrichtung ohne Gewinnerzielungsabsicht', 28.0)

# %%
# Average age of enterprises by Nace code
query4 = """
SELECT
    NaceCode,
    AVG((julianday('now') - julianday(StartDate_ISO)) / 365.25) AS average_age_years
FROM
    enterprise
    INNER JOIN activity ON activity.EntityNumber = enterprise.EnterpriseNumber
GROUP BY
    NaceCode
ORDER BY average_age_years DESC
LIMIT 100
"""
execute_query(query4)
# Out:
# (80226, 96.48851370646106)
# (75302, 81.02048641091837)
# (10100, 68.73875326840493)
# (70202, 66.53313188974334)
# (75114, 62.9098689426007)
# (66033, 60.477692677159546)
# (26240, 60.13669988031459)
# (84114, 59.91288191270181)
# (11100, 59.82937612945901)
# (75220, 57.56448906580398)
# (91310, 56.75960119689872)
# (84232, 56.10247674547544)
# (75232, 56.10247674547544)
# (80224, 55.94799014860153)
# (65222, 55.57684319497308)
# (75115, 55.23571881711587)
# (26402, 54.489882631854634)
# (75303, 54.36300946133604)
# (80103, 54.31739803226531)
# (84115, 53.87206047720787)
# (75111, 53.50537637835453)
# (66031, 52.35598461679645)
# (80105, 52.19100058759272)
# (66020, 51.79740194348072)
# (41000, 51.61694591438872)
# (1412, 51.267432255400145)
# (80214, 50.79797903947997)
# (27441, 50.72259994876086)
# (24110, 50.69279470951003)
# (27451, 50.66620022254594)
# (85324, 50.21414644108622)
# (94910, 50.13888615860418)
# (91200, 50.12719488890266)
# (55210, 49.63786346689912)
# (26810, 49.30389544997423)
# (85313, 49.246150327833504)
# (29130, 49.241618233692904)
# (75130, 49.199004238060425)
# (80304, 48.99894737500561)
# (84302, 48.60264152353207)
# (24151, 48.295463390493985)
# (75301, 48.17658124011381)
# (32202, 48.03354732565823)
# (85322, 47.865830105680274)
# (17150, 47.69805707206193)
# (27442, 47.63247902701776)
# (28743, 47.50406078771657)
# (29540, 47.46718128574466)
# (66013, 47.29804640511081)
# (14122, 47.281199733644016)
# (16000, 47.27206554134761)
# (15430, 47.1629376170246)
# (65120, 46.91354296172149)
# (75113, 46.76421528072527)
# (85314, 46.33394884209613)
# (36620, 46.135239693228115)
# (27340, 46.0850457621307)
# (24130, 45.96154763124037)
# (21240, 45.77334796870805)
# (85110, 45.763872662674785)
# (60211, 45.643010626378924)
# (28751, 45.49630354381969)
# (86102, 45.49129718809465)
# (14300, 45.395524560083835)
# (15920, 45.08700788852814)
# (15610, 45.05004690290186)
# (15620, 44.983699652160354)
# (18300, 44.958739579151)
# (17170, 44.59346465330113)
# (21122, 44.5876945591691)
# (28742, 44.34135422665271)
# (80219, 44.26583517577432)
# (55231, 44.16837797076007)
# (24620, 44.02738140959981)
# (85326, 43.85830101601565)
# (87901, 43.82493508079849)
# (23300, 43.78351712877455)
# (27540, 43.68541080890232)
# (87991, 43.65765527395992)
# (17510, 43.652169897368154)
# (24170, 43.637042111662986)
# (91311, 43.28440693028036)
# (24300, 43.28046337212736)
# (26650, 43.02458489058153)
# (85206, 43.006053063066126)
# (25130, 42.985167444387905)
# (28610, 42.78263710530725)
# (60212, 42.78177663791701)
# (24120, 42.74609983468375)
# (15710, 42.62300525101744)
# (31400, 42.559697826926495)
# (21230, 42.31061292379285)
# (24700, 42.277699195851895)
# (15960, 42.14970467155347)
# (15980, 42.135787263385545)
# (65223, 41.98763911523739)
# (87201, 41.97728892324133)
# (15830, 41.931752192820696)
# (63404, 41.70992813937447)
# (24511, 41.66434009451115)

# %%
# Percentage of enterprises by juridical form
query5 = """
SELECT
    COUNT(*) AS entity_count,
    Description,
    enterprise.JuridicalForm,
    ROUND(COUNT(*) * 100.0 / (SELECT COUNT(*) FROM enterprise WHERE JuridicalForm IS NOT NULL), 2) AS percentage
FROM
    enterprise
    LEFT JOIN code ON code.Code = enterprise.JuridicalForm 
        AND code.Category = 'JuridicalForm'
        AND code.Language = 'NL'  
WHERE enterprise.JuridicalForm IS NOT NULL
GROUP BY
    enterprise.JuridicalForm, Description
HAVING entity_count > 0
ORDER BY entity_count DESC
"""

execute_query(query5)
# Out:
# (493384, 'Besloten Vennootschap', 610.0, 42.78)
# (139213, 'Vereniging zonder winstoogmerk', 17.0, 12.07)
# (108445, 'Vereniging van mede-eigenaars', 70.0, 9.4)
# (86541, 'Besloten vennootschap met beperkte aansprakelijkheid', 15.0, 7.5)
# (80675, 'Naamloze vennootschap', 14.0, 7.0)
# (67576, 'Buitenlandse entiteit', 30.0, 5.86)
# (47352, 'Commanditaire vennootschap', 612.0, 4.11)
# (27737, 'Vennootschap of vereniging zonder rechtspersoonlijkheid', 721.0, 2.41)
# (24888, 'Vennootschap onder firma', 11.0, 2.16)
# (16182, 'Gewone commanditaire vennootschap', 12.0, 1.4)
# (12149, 'Buitenlandse entiteit zonder Belgische vestiging met vertegenwoordiger voor BTW', 235.0, 1.05)
# (8320, 'BTW-eenheid', 3.0, 0.72)
# (7189, 'Coöperatieve vennootschap (oud statuut)', 16.0, 0.62)
# (4870, 'Openbare instelling', 124.0, 0.42)
# (4111, 'Coöperatieve vennootschap met beperkte aansprakelijkheid', 8.0, 0.36)
# (3898, 'Buitenlandse entiteit met onroerend goed in België (met rechtspersoonlijkheid)', 230.0, 0.34)
# (2862, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid', 6.0, 0.25)
# (2502, 'Internationale vereniging zonder winstoogmerk', 125.0, 0.22)
# (2245, 'Private stichting', 26.0, 0.19)
# (1753, 'Coöperatieve vennootschap', 706.0, 0.15)
# (1678, 'Ziekenfonds / Maatschappij van onderlinge bijstand / Landsbond van ziekenfondsen', 19.0, 0.15)
# (1283, 'Beroepsvereniging', 20.0, 0.11)
# (931, 'Ongekende rechtsvorm RSZ', 999.0, 0.08)
# (790, 'Internationale wetenschappelijke organisatie van Belgisch recht', 22.0, 0.07)
# (732, 'Stichting van openbaar nut', 29.0, 0.06)
# (567, 'Openbaar centrum voor maatschappelijk welzijn', 412.0, 0.05)
# (565, 'Stad / gemeente', 411.0, 0.05)
# (376, 'Landbouwvennootschap', 25.0, 0.03)
# (361, 'Buitenlandse of internationale publieke organisatie', 160.0, 0.03)
# (342, 'Commanditaire vennootschap op aandelen', 13.0, 0.03)
# (332, 'Polder / Watering', 129.0, 0.03)
# (299, 'Autonoom gemeentebedrijf', 418.0, 0.03)
# (279, 'Andere rechtsvorm', 151.0, 0.02)
# (268, 'Europees economisch samenwerkingsverband', 65.0, 0.02)
# (244, 'Andere privaatrechtelijke vorm met rechtspersoonlijkheid', 51.0, 0.02)
# (200, 'Buitenlandse onderneming zonder Belgische vestiging genoteerd op de beurs', 453.0, 0.02)
# (186, 'Lokale politiezone', 413.0, 0.02)
# (173, 'Instelling van openbaar nut', 18.0, 0.02)
# (139, 'Organisme voor de Financiering van Pensioenen', 2.0, 0.01)
# (134, 'Economisch samenwerkingsverband', 60.0, 0.01)
# (124, "Vereniging van OCMW's", 420.0, 0.01)
# (122, 'Organismen ingeschreven voorde R.V.P.', 451.0, 0.01)
# (110, 'Coöperatieve vennootschap met beperkte aansprakelijkheid met een sociaal oogmerk', 508.0, 0.01)
# (82, 'Besloten Vennootschap van publiek recht', 616.0, 0.01)
# (76, 'Naamloze vennootschap van publiek recht', 114.0, 0.01)
# (73, 'Projectvereniging', 415.0, 0.01)
# (60, 'Onderlinge verzekeringsvereniging / Gemeenschappelijke verzekeringskas van privaat recht', 21.0, 0.01)
# (60, 'Ministerie van Binnenlandse Zaken', 379.0, 0.01)
# (54, 'Opdrachthoudende vereniging (Vlaams Gewest)', 417.0, 0.0)
# (47, 'Andere federale dienst', 303.0, 0.0)
# (43, 'Overheid van het Vlaamse Gewest en van de Vlaamse Gemeenschap', 310.0, 0.0)
# (38, 'Coöperatieve vennootschap van publiek recht (oud statuut)', 116.0, 0.0)
# (38, 'Buitenlandse entiteit met onroerend goed in België (zonder rechtspersoonlijkheid)', 454.0, 0.0)
# (35, 'Tijdelijke vereniging', 722.0, 0.0)
# (34, 'Besloten vennootschap met beperkte aansprakelijkheid met een sociaal oogmerk', 515.0, 0.0)
# (33, 'Hulpverleningszone', 422.0, 0.0)
# (32, 'Buitenlandse privaatrechtelijke vereniging met vestiging in België', 23.0, 0.0)
# (27, 'Vereniging zonder winstoogmerk van publiek recht', 117.0, 0.0)
# (26, 'Dienstverlenende vereniging (Vlaams Gewest)', 416.0, 0.0)
# (26, 'Autonoom provinciebedrijf', 419.0, 0.0)
# (24, 'Beroepsvereniging / Orde', 123.0, 0.0)
# (20, 'Intercommunale', 414.0, 0.0)
# (19, 'Organisme ingeschreven voor de Administratie van de Pensioenen', 452.0, 0.0)
# (18, 'Maatschap', 702.0, 0.0)
# (16, 'Provinciale overheid', 400.0, 0.0)
# (14, 'Overheid van de Franse Gemeenschap', 340.0, 0.0)
# (13, 'Europese vennootschap (Societas Europaea)', 27.0, 0.0)
# (12, 'Federale overheidsdienst', 301.0, 0.0)
# (10, 'Coöperatieve vennootschap met beperkte aansprakelijkheid, bij wijze van deelneming', 9.0, 0.0)
# (10, 'Overheid van het Brusselse Hoofdstedelijk Gewest', 330.0, 0.0)
# (10, 'Naamloze vennootschap met een sociaal oogmerk', 514.0, 0.0)
# (9, 'Coöperatieve vennootschap met beperkte aansprakelijkheid van publiek recht', 108.0, 0.0)
# (9, 'Gewone commanditaire vennootschap met een sociaal oogmerk', 512.0, 0.0)
# (8, 'Overheid van het Waalse Gewest', 320.0, 0.0)
# (7, 'Europese Coöperatieve Vennootschap', 1.0, 0.0)
# (7, 'Europese politieke partij', 217.0, 0.0)
# (7, 'Overheid van de Duitstalige Gemeenschap', 350.0, 0.0)
# (6, 'Europees economisch samenwerkingsverband zonder zetel met vestiging in België (EESV)', 265.0, 0.0)
# (6, 'Ministerie van het Waalse Gewest', 388.0, 0.0)
# (6, 'Coöperatieve vennootschap van publiek recht', 716.0, 0.0)
# (5, 'Kongolese vennootschap', 40.0, 0.0)
# (5, 'Europese politieke stichting', 218.0, 0.0)
# (5, 'Ministerie van de Franse Gemeenschap', 386.0, 0.0)
# (5, 'Diversen zonder rechtspersoonlijkheid', 790.0, 0.0)
# (4, 'Rijk, Provincie, Gewest, Gemeenschap', 110.0, 0.0)
# (4, 'Ministerie van de Vlaamse Gemeenschap', 385.0, 0.0)
# (4, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid met een sociaal oogmerk', 506.0, 0.0)
# (4, 'Economisch samenwerkingsverband met een sociaal oogmerk', 560.0, 0.0)
# (3, 'Andere', 393.0, 0.0)
# (2, 'Coöperatieve vennootschap met onbeperkte aansprakelijkheid, bij wijze van deelneming', 7.0, 0.0)
# (2, 'Programmatorische federale overheidsdienst', 302.0, 0.0)
# (2, 'Internationale vereniging zonder winstoogmerk van publiek recht', 325.0, 0.0)
# (2, 'Ministerie van Economische Zaken', 370.0, 0.0)
# (1, 'Instelling zonder winstoogmerk', 28.0, 0.0)
# (1, 'Berg van Barmhartigheid', 127.0, 0.0)
# (1, 'Ministerie van Buitenlandse Zaken, Buitenlandse handel en Ontwikkelingssamenwerking', 371.0, 0.0)
# (1, 'Ministerie van Middenstand', 373.0, 0.0)
# (1, 'Ministerie van Justitie', 380.0, 0.0)
# (1, 'Diensten van de Eerste Minister', 383.0, 0.0)
# (1, 'Ministerie van het Brusselse Hoofdstedelijk Gewest', 387.0, 0.0)
# (1, 'Vennootschap onder firma met een sociaal oogmerk', 511.0, 0.0)
# (1, 'Commanditaire vennootschap op aandelen met een sociaal oogmerk', 513.0, 0.0)
# (1, 'Commanditaire vennootschap van publiek recht', 617.0, 0.0)
# (1, 'Andere vorm met een sociaal oogmerk van publiek recht', 651.0, 0.0)
# (1, 'Vakbond', 724.0, 0.0)

# %%
# Distribution of companies outside Belgium
query6 = """
SELECT COUNT(*) as count, CountryNL
FROM address
where Zipcode IS NULL
GROUP BY CountryNL
ORDER BY count DESC
"""
execute_query(query6)
# Out:
# (2209, 'Duitsland (Bondsrep.)')
# (1988, 'Groot-Brittannië')
# (1291, 'Luxemburg (Groot-Hertogdom)')
# (1156, 'Verenigde Staten van Amerika')
# (720, 'Zwitserland')
# (654, 'Frankrijk')
# (336, 'Italië')
# (284, 'Nederland')
# (179, 'Liechtenstein')
# (178, 'Ierland /Eire/')
# (166, 'Spanje')
# (162, 'Zweden')
# (110, 'Panama')
# (95, 'Maagdeneilanden')
# (94, 'Denemarken')
# (88, 'Japan')
# (83, 'Oostenrijk')
# (79, 'Canada')
# (77, 'Portugal')
# (74, 'Finland')
# (72, 'Gibraltar')
# (67, 'Nederlandse Antillen')
# (67, 'Congo (Dem. Rep.)')
# (54, 'Noorwegen')
# (32, 'Liberia')
# (31, 'Zuid-Afrika /Rep./')
# (31, 'Israël')
# (27, 'Griekenland')
# (26, 'Onbepaald')
# (22, 'Cyprus')
# (20, 'Duitsland (Dem. rep.)')
# (20, 'Australië')
# (19, 'Monaco /Vorstendom/')
# (18, 'Turkije')
# (17, 'India')
# (17, 'Bahamas')
# (16, 'Marokko')
# (15, 'Roemenië')
# (14, 'Joegoslavië (Servië-Montenegro)')
# (13, 'Libanon')
# (13, 'Hong Kong(V.K.)')
# (12, 'Polen ( Rep. )')
# (9, 'Tunesië')
# (9, 'China /Volksrep./')
# (9, 'Andorra')
# (8, 'Singapore')
# (8, 'Nieuw-Zeeland')
# (8, 'Malta')
# (7, 'Zuid-Korea ( Rep. )')
# (7, 'Unie d. Socialist. Sovjetrep.')
# (6, 'Ijsland')
# (6, 'Hongarije ( Rep. )')
# (5, 'Tsjecho-Slovakije')
# (5, 'Rwanda /Rep./')
# (5, 'Maleisië')
# (5, 'Iran')
# (5, 'Indonesië')
# (5, 'Albanië')
# (4, 'Thailand')
# (4, 'Rusland ( Federatie van )')
# (4, 'Filippijnen')
# (4, 'China-Taïwan ( Rep. )')
# (4, 'Caïmanes(V.K.)')
# (4, 'Burundi')
# (4, 'Bulgarije')
# (4, 'Britse Antillen')
# (4, "Bermuda's")
# (4, 'Argentinië')
# (3, 'Verenigde Arabische Emiraten')
# (3, 'Venezuela')
# (3, 'Turks en Caicos Eilanden')
# (3, 'Saoedi-Arabië')
# (3, 'Pakistan')
# (3, 'Hong-Kong')
# (3, 'Congo(Volksrep.)')
# (3, 'Brazilië')
# (3, 'Barbados')
# (2, 'Zambia')
# (2, 'Tsjechische Republiek')
# (2, 'Seychellen (Eilanden)')
# (2, 'Saint Vincent')
# (2, 'Mexico')
# (2, 'Lesotho')
# (2, 'Jordanië')
# (2, 'Guatemala')
# (2, 'Franse Antillen')
# (2, 'El Salvador')
# (2, 'Cuba')
# (2, 'Colombia')
# (2, 'Botswana')
# (2, 'Bolivië')
# (2, 'Belize')
# (2, "Bahama's")
# (2, 'Amerikaanse Antillen')
# (2, 'Algerije')
# (1, 'Zaïre (Republiek)')
# (1, 'West-Samoa')
# (1, 'Vanuatu')
# (1, 'Uganda')
# (1, 'Tuvalu')
# (1, 'Turkmenistan ( Rep. )')
# (1, 'Togo')
# (1, 'Tanzania /Verenigde Rep./')
# (1, 'Syrië(Syrisch-Arabische Rep.)')
# (1, 'Swaziland')
# (1, 'Suriname')
# (1, 'Sri Lanka')
# (1, 'Somalië(Rep.)')
# (1, 'Socialistische Republiek Vietnam')
# (1, 'Senegal')
# (1, 'San Marino')
# (1, 'Rhodesië')
# (1, 'Peru')
# (1, 'Paraguay')
# (1, 'Oekraïne ( Rep. )')
# (1, 'Noord-Korea ( Volksrep. )')
# (1, 'Niue-eiland(N-Z.)')
# (1, 'Nigeria (Fed.Rep.)')
# (1, 'Nieuw-Caledonië')
# (1, 'Myanmar (Unie van)')
# (1, 'Mauritius /Eiland/')
# (1, 'Libië')
# (1, 'Koeweit/Vorstendom/')
# (1, 'Kitts and Nevis(V.K.)')
# (1, 'Joegoslavië')
# (1, 'Ivoorkust')
# (1, 'Irak')
# (1, 'Honduras')
# (1, 'Guinea')
# (1, 'Groenland(D.K.)')
# (1, 'Ghana')
# (1, 'Gambia')
# (1, 'Gabon')
# (1, 'Frans Guyana')
# (1, 'Ethiopië')
# (1, 'Dominikaanse Republiek')
# (1, 'Dominica (Republiek)')
# (1, 'Democratische Republ. Madagascar')
# (1, 'Cambodja')
# (1, 'Brunei')
# (1, 'Benin(Volksrepubliek)')
# (1, 'Bangladesh')
# (1, 'Bahrein')

# %%
# Count of enterprises by starting month
query7 = """
    SELECT 
    	COUNT(*) AS count,  
    	strftime('%m', StartDate_ISO) AS month
    FROM enterprise
    GROUP BY month
    ORDER BY count DESC
"""
execute_query(query7)
# Out:
# (262813, '01')
# (220905, '10')
# (190441, '04')
# (172372, '07')
# (152819, '12')
# (144267, '02')
# (140084, '03')
# (130018, '09')
# (129974, '05')
# (129013, '06')
# (128929, '11')
# (124611, '08')

# %%
# nr of enterprises created by year
query8 = """
    SELECT 
    	COUNT(*) AS count,  
    	strftime('%Y', StartDate_ISO) AS year
    FROM enterprise
    GROUP BY year
    ORDER BY count DESC
"""
execute_query(query8)
# Out:
# (130923, '2024')
# (115432, '2023')
# (105626, '2022')
# (100446, '2021')
# (84786, '2020')
# (81171, '2019')
# (74092, '2025')
# (73309, '2018')
# (66413, '2017')
# (61028, '2016')
# (52542, '2015')
# (49466, '2014')
# (44352, '2011')
# (43779, '2013')
# (42024, '2012')
# (41178, '2010')
# (40525, '1995')
# (37958, '2007')
# (37820, '2008')
# (36784, '2009')
# (34056, '2006')
# (30255, '2005')
# (27495, '2004')
# (24043, '2002')
# (23838, '2003')
# (23660, '2001')
# (23337, '2000')
# (23217, '1998')
# (22421, '1999')
# (21951, '1996')
# (21754, '1997')
# (20339, '1992')
# (19847, '1989')
# (19358, '1993')
# (19129, '1994')
# (18941, '1991')
# (18477, '1990')
# (17549, '1988')
# (15386, '1987')
# (13429, '1986')
# (12663, '1968')
# (11487, '1985')
# (10515, '1983')
# (10428, '1984')
# (9013, '1971')
# (8816, '1982')
# (7598, '1981')
# (7350, '1980')
# (6898, '1978')
# (6810, '1979')
# (6752, '1977')
# (6267, '1976')
# (5776, '1800')
# (5531, '1975')
# (4884, '1974')
# (4643, '1973')
# (4053, '1972')
# (3624, '1969')
# (3503, '1970')
# (2422, '1967')
# (2019, '1966')
# (1974, '1965')
# (1629, '1964')
# (1436, '1961')
# (1403, '1963')
# (1294, '1962')
# (1181, '1960')
# (1125, '1959')
# (829, '1957')
# (808, '1956')
# (796, '1955')
# (786, '1958')
# (723, '1945')
# (643, '1948')
# (631, '1954')
# (630, '1946')
# (621, '1947')
# (617, '1953')
# (589, '1952')
# (570, '1949')
# (567, '1950')
# (538, '1938')
# (528, '1922')
# (523, '1951')
# (373, '1939')
# (348, '1941')
# (348, '1923')
# (338, '1937')
# (247, '1929')
# (243, '1928')
# (233, '1936')
# (233, '1935')
# (231, '1925')
# (211, '1940')
# (209, '1924')
# (196, '1931')
# (191, '1932')
# (189, '1930')
# (184, '1942')
# (181, '1944')
# (179, '1926')
# (177, '1933')
# (170, '1927')
# (169, '1934')
# (142, '1921')
# (131, '1943')
# (111, '1920')
# (110, '1919')
# (98, '1913')
# (83, '1900')
# (74, '1912')
# (71, '1910')
# (69, '1911')
# (65, '1898')
# (62, '1899')
# (62, '1897')
# (62, '1896')
# (60, '1906')
# (53, '1914')
# (50, '1908')
# (49, '1905')
# (48, '1909')
# (45, '1895')
# (43, '1907')
# (43, '1904')
# (42, '1901')
# (33, '1894')
# (33, '1892')
# (30, '1903')
# (24, '1902')
# (21, '1891')
# (20, '1917')
# (18, '1893')
# (16, '1890')
# (13, '1916')
# (12, '1889')
# (12, '1888')
# (12, '1887')
# (11, '1918')
# (10, '1886')
# (10, '1877')
# (9, '1915')
# (8, '1874')
# (7, '1876')
# (6, '1882')
# (6, '1879')
# (5, '1883')
# (5, '1881')
# (5, '1880')
# (3, '1884')
# (3, '1872')
# (3, '1842')
# (3, '1830')
# (3, '1815')
# (3, '1810')
# (3, '1809')
# (2, '1885')
# (2, '1868')
# (2, '1865')
# (2, '1863')
# (2, '1860')
# (2, '1853')
# (2, '1850')
# (2, '1848')
# (2, '1835')
# (2, '1831')
# (2, '1804')
# (1, '1878')
# (1, '1875')
# (1, '1871')
# (1, '1870')
# (1, '1869')
# (1, '1864')
# (1, '1859')
# (1, '1856')
# (1, '1855')
# (1, '1854')
# (1, '1851')
# (1, '1849')
# (1, '1845')
# (1, '1841')
# (1, '1836')
# (1, '1829')
# (1, '1825')
# (1, '1819')
# (1, '1817')
# (1, '1816')
# (1, '1814')
# (1, '1813')
# (1, '1803')
# (1, '1802')
# (1, '1618')

# %%
# Company creation trends - year over year growth
query9 = """
SELECT 
    year,
    count AS companies_created,
    LAG(count) OVER (ORDER BY year) AS previous_year,
    ROUND(((count - LAG(count) OVER (ORDER BY year)) * 100.0 / 
           LAG(count) OVER (ORDER BY year)), 2) AS growth_percentage
FROM (
    SELECT 
        strftime('%Y', StartDate_ISO) AS year,
        COUNT(*) AS count
    FROM enterprise
    WHERE StartDate_ISO IS NOT NULL
    GROUP BY year
    ORDER BY year
) 
WHERE year >= '2005' and year < '2025'
ORDER BY growth_percentage DESC
"""

execute_query(query9)
# Out:
# ('2021', 100446, 84786, 18.47)
# ('2016', 61028, 52542, 16.15)
# ('2024', 130923, 115432, 13.42)
# ('2014', 49466, 43779, 12.99)
# ('2006', 34056, 30255, 12.56)
# ('2010', 41178, 36784, 11.95)
# ('2007', 37958, 34056, 11.46)
# ('2019', 81171, 73309, 10.72)
# ('2018', 73309, 66413, 10.38)
# ('2023', 115432, 105626, 9.28)
# ('2017', 66413, 61028, 8.82)
# ('2011', 44352, 41178, 7.71)
# ('2015', 52542, 49466, 6.22)
# ('2022', 105626, 100446, 5.16)
# ('2020', 84786, 81171, 4.45)
# ('2013', 43779, 42024, 4.18)
# ('2008', 37820, 37958, -0.36)
# ('2009', 36784, 37820, -2.74)
# ('2012', 42024, 44352, -5.25)
# ('2005', 30255, None, None)

# %%
# Debug: Check what types of address situations exist
debug_query = """
SELECT 
    'Enterprises with Belgian addresses' as category,
    COUNT(DISTINCT enterprise.EnterpriseNumber) as count
FROM enterprise
INNER JOIN address ON enterprise.EnterpriseNumber = address.EntityNumber
WHERE address.Zipcode IS NOT NULL

UNION ALL

SELECT 
    'Enterprises with foreign addresses' as category,
    COUNT(DISTINCT enterprise.EnterpriseNumber) as count
FROM enterprise
INNER JOIN address ON enterprise.EnterpriseNumber = address.EntityNumber
WHERE address.Zipcode IS NULL

UNION ALL

SELECT 
    'Enterprises with NO address records' as category,
    COUNT(DISTINCT enterprise.EnterpriseNumber) as count
FROM enterprise
LEFT JOIN address ON enterprise.EnterpriseNumber = address.EntityNumber
WHERE address.EntityNumber IS NULL

UNION ALL

SELECT 
    'Total enterprises' as category,
    COUNT(DISTINCT EnterpriseNumber) as count
FROM enterprise
"""

execute_query(debug_query)
# Out:
# ('Enterprises with Belgian addresses', 1142297)
# ('Enterprises with foreign addresses', 10904)
# ('Enterprises with NO address records', 773045)
# ('Total enterprises', 1926246)

# %%
# Nace code distribution for enterprises abroad
query11 = """
SELECT 
    NaceCode, 
    COUNT(DISTINCT activity.EntityNumber) as enterprise_count,
    ROUND(COUNT(DISTINCT activity.EntityNumber) * 100.0 / (
        SELECT COUNT(DISTINCT activity.EntityNumber) 
        FROM address 
        INNER JOIN activity ON activity.EntityNumber = address.EntityNumber 
        WHERE Zipcode IS NULL
    ), 2) AS percentage
FROM address
INNER JOIN activity ON activity.EntityNumber = address.EntityNumber
WHERE Zipcode IS NULL
GROUP BY NaceCode
ORDER BY enterprise_count DESC
"""
execute_query(query11)
# Out:
# (51550, 16, 7.44)
# (46851, 16, 7.44)
# (46751, 16, 7.44)
# (94110, 13, 6.05)
# (91110, 12, 5.58)
# (99000, 9, 4.19)
# (46720, 9, 4.19)
# (51872, 8, 3.72)
# (51460, 8, 3.72)
# (46460, 8, 3.72)
# (46699, 7, 3.26)
# (46649, 7, 3.26)
# (45310, 7, 3.26)
# (73300, 6, 2.79)
# (70210, 6, 2.79)
# (62100, 6, 2.79)
# (97000, 5, 2.33)
# (95000, 5, 2.33)
# (71121, 5, 2.33)
# (51100, 5, 2.33)
# (50301, 5, 2.33)
# (74203, 4, 1.86)
# (73200, 4, 1.86)
# (70220, 4, 1.86)
# (70200, 4, 1.86)
# (52100, 4, 1.86)
# (51180, 4, 1.86)
# (46820, 4, 1.86)
# (46180, 4, 1.86)
# (94999, 3, 1.4)
# (94992, 3, 1.4)
# (92400, 3, 1.4)
# (91330, 3, 1.4)
# (74142, 3, 1.4)
# (74141, 3, 1.4)
# (74131, 3, 1.4)
# (72100, 3, 1.4)
# (63910, 3, 1.4)
# (63122, 3, 1.4)
# (62200, 3, 1.4)
# (62020, 3, 1.4)
# (60310, 3, 1.4)
# (52290, 3, 1.4)
# (52250, 3, 1.4)
# (51900, 3, 1.4)
# (51810, 3, 1.4)
# (51562, 3, 1.4)
# (51541, 3, 1.4)
# (51520, 3, 1.4)
# (51130, 3, 1.4)
# (47910, 3, 1.4)
# (46900, 3, 1.4)
# (46869, 3, 1.4)
# (46841, 3, 1.4)
# (46769, 3, 1.4)
# (46741, 3, 1.4)
# (46620, 3, 1.4)
# (46130, 3, 1.4)
# (45340, 3, 1.4)
# (43299, 3, 1.4)
# (43240, 3, 1.4)
# (94200, 2, 0.93)
# (94120, 2, 0.93)
# (91120, 2, 0.93)
# (82990, 2, 0.93)
# (81220, 2, 0.93)
# (74879, 2, 0.93)
# (74111, 2, 0.93)
# (73100, 2, 0.93)
# (72220, 2, 0.93)
# (72190, 2, 0.93)
# (72109, 2, 0.93)
# (70311, 2, 0.93)
# (70100, 2, 0.93)
# (69101, 2, 0.93)
# (68311, 2, 0.93)
# (68310, 2, 0.93)
# (62010, 2, 0.93)
# (52610, 2, 0.93)
# (51871, 2, 0.93)
# (51561, 2, 0.93)
# (51532, 2, 0.93)
# (51476, 2, 0.93)
# (51410, 2, 0.93)
# (51160, 2, 0.93)
# (51140, 2, 0.93)
# (47120, 2, 0.93)
# (46861, 2, 0.93)
# (46810, 2, 0.93)
# (46761, 2, 0.93)
# (46710, 2, 0.93)
# (46693, 2, 0.93)
# (46643, 2, 0.93)
# (46499, 2, 0.93)
# (46496, 2, 0.93)
# (46431, 2, 0.93)
# (46412, 2, 0.93)
# (46160, 2, 0.93)
# (46140, 2, 0.93)
# (45331, 2, 0.93)
# (43222, 2, 0.93)
# (43211, 2, 0.93)
# (29230, 2, 0.93)
# (28250, 2, 0.93)
# (23200, 2, 0.93)
# (19200, 2, 0.93)
# (94993, 1, 0.47)
# (93191, 1, 0.47)
# (92621, 1, 0.47)
# (91200, 1, 0.47)
# (90021, 1, 0.47)
# (85599, 1, 0.47)
# (85319, 1, 0.47)
# (84119, 1, 0.47)
# (82920, 1, 0.47)
# (82300, 1, 0.47)
# (82110, 1, 0.47)
# (82100, 1, 0.47)
# (80215, 1, 0.47)
# (77110, 1, 0.47)
# (74872, 1, 0.47)
# (74855, 1, 0.47)
# (74820, 1, 0.47)
# (74700, 1, 0.47)
# (74302, 1, 0.47)
# (74152, 1, 0.47)
# (71209, 1, 0.47)
# (71100, 1, 0.47)
# (68321, 1, 0.47)
# (67130, 1, 0.47)
# (66290, 1, 0.47)
# (66199, 1, 0.47)
# (65200, 1, 0.47)
# (65120, 1, 0.47)
# (64999, 1, 0.47)
# (64190, 1, 0.47)
# (64120, 1, 0.47)
# (63406, 1, 0.47)
# (63402, 1, 0.47)
# (63121, 1, 0.47)
# (60241, 1, 0.47)
# (60211, 1, 0.47)
# (59140, 1, 0.47)
# (53200, 1, 0.47)
# (52502, 1, 0.47)
# (52487, 1, 0.47)
# (52431, 1, 0.47)
# (51880, 1, 0.47)
# (51850, 1, 0.47)
# (51820, 1, 0.47)
# (51542, 1, 0.47)
# (51510, 1, 0.47)
# (51478, 1, 0.47)
# (51477, 1, 0.47)
# (51475, 1, 0.47)
# (51471, 1, 0.47)
# (51450, 1, 0.47)
# (51430, 1, 0.47)
# (51250, 1, 0.47)
# (51190, 1, 0.47)
# (51170, 1, 0.47)
# (51120, 1, 0.47)
# (50101, 1, 0.47)
# (49420, 1, 0.47)
# (49310, 1, 0.47)
# (47990, 1, 0.47)
# (47792, 1, 0.47)
# (47721, 1, 0.47)
# (47410, 1, 0.47)
# (47400, 1, 0.47)
# (46842, 1, 0.47)
# (46839, 1, 0.47)
# (46831, 1, 0.47)
# (46742, 1, 0.47)
# (46739, 1, 0.47)
# (46731, 1, 0.47)
# (46711, 1, 0.47)
# (46695, 1, 0.47)
# (46692, 1, 0.47)
# (46660, 1, 0.47)
# (46645, 1, 0.47)
# (46642, 1, 0.47)
# (46630, 1, 0.47)
# (46610, 1, 0.47)
# (46500, 1, 0.47)
# (46498, 1, 0.47)
# (46494, 1, 0.47)
# (46492, 1, 0.47)
# (46450, 1, 0.47)
# (46423, 1, 0.47)
# (46421, 1, 0.47)
# (46350, 1, 0.47)
# (46349, 1, 0.47)
# (46215, 1, 0.47)
# (46190, 1, 0.47)
# (46170, 1, 0.47)
# (46120, 1, 0.47)
# (45450, 1, 0.47)
# (45422, 1, 0.47)
# (45421, 1, 0.47)
# (45215, 1, 0.47)
# (45111, 1, 0.47)
# (43992, 1, 0.47)
# (43390, 1, 0.47)
# (43350, 1, 0.47)
# (43320, 1, 0.47)
# (42220, 1, 0.47)
# (42110, 1, 0.47)
# (38330, 1, 0.47)
# (38219, 1, 0.47)
# (36141, 1, 0.47)
# (34100, 1, 0.47)
# (33202, 1, 0.47)
# (31091, 1, 0.47)
# (31004, 1, 0.47)
# (30020, 1, 0.47)
# (29420, 1, 0.47)
# (29120, 1, 0.47)
# (29100, 1, 0.47)
# (28410, 1, 0.47)
# (28120, 1, 0.47)
# (28110, 1, 0.47)
# (27100, 1, 0.47)
# (26800, 1, 0.47)
# (26700, 1, 0.47)
# (26510, 1, 0.47)
# (26200, 1, 0.47)
# (25991, 1, 0.47)
# (24660, 1, 0.47)
# (24650, 1, 0.47)
# (24140, 1, 0.47)
# (24100, 1, 0.47)
# (21220, 1, 0.47)
# (21121, 1, 0.47)
# (20590, 1, 0.47)
# (20140, 1, 0.47)
